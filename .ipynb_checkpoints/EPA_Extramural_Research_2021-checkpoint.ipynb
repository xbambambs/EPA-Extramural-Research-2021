# %%
import numpy as np
import pandas as pd
import json

# %%
f = open('/Users/bminaru/Documents/DS/1_PROJECTS/EPA/0_ASSETS/Extramural_Research.json')

# %%
data = json.load(f)
data
# Out:
# {'@context': 'https://project-open-data.cio.gov/v1.1/schema/catalog.jsonld',
#  '@id': 'https://edg.epa.gov/metadata/RestQueryServlet?f=dcat&searchText=metadataFormat:(iso)&owner=106&max=350',
#  '@type': 'dcat:Catalog',
#  'conformsTo': 'https://project-open-data.cio.gov/v1.1/schema',
#  'describedBy': 'https://project-open-data.cio.gov/v1.1/schema/catalog.json',
#  'dataset': [{'@type': 'dcat:Dataset',
#    'title': '[Extramural Research] NCEE EJ Satellite Data',
#    'description': 'The project looks to assess how recent advances in the atmospheric sciences literature that uses remotely sensed information to estimate finely resolved ground-level measures of fine particulate matter can be leveraged to explore environmental justice issues. We also are working to compare these data with more traditional ways to characterize average air concentrations in unmonitored areas based on EPAs air quality monitors and modeling.',
#    'modified': '2021-06-24',
# ...
